# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spotify = pd.read_csv('spotify.csv')
spotify['Date'] = pd.to_datetime(spotify['Date'], format='%m/%d/%Y')
#spotify['Date'] = spotify['Date'].dt.to_period('M')

#spotify_g = spotify.groupby(by='Date', as_index=False).mean().round()
spotify['Date'] = spotify['Date'].dt.strftime("%Y-%m-%d")
#print(spotify_g.head())

# %%
# Change the style of plot
plt.style.use('seaborn-darkgrid')
 
# Create a color palette
palette = plt.get_cmap('Set1')

# Adjust figure size
plt.figure(figsize=(16, 5))

# Plot multiple lines
num=0
for column in spotify_g.drop('Date', axis=1):
    num+=1
    plt.plot(spotify['Date'], spotify[column], marker='', color=palette(num), linewidth=1, alpha=0.9, label=column)

# Add legend
plt.legend(loc=2, ncol=5, fontsize=12)
 
# Add titles
plt.title("Daily Global Streams of Popular Songs in 2017-2018", fontsize=30, fontweight=0, color='black')
plt.xlabel("Time")
plt.ylabel("Stream")
plt.xticks(rotation=90)

# Show the graph
plt.show()
